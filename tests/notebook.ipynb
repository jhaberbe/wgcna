# %%
import sys
sys.path.append("../src/wgcna")

# %%
import adjacency
import common
import connectivity
import wgcna

# %%
import scanpy as sc

adata = sc.read_h5ad("/Users/jameshaberberger/GitHub/29Mar2024_atm_shiny/adata.h5ad")

# %%
microglia = adata[adata.obs["celltype"] == "Microglia"].copy()
microglia = common.annotate_gene_groups(microglia)
microglia = common.select_genes(microglia, percent_threshold=0.01)
# Out:
# /Users/jameshaberberger/Library/Python/3.11/lib/python/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/Library/Python/3.11/lib/python/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/Library/Python/3.11/lib/python/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/Library/Python/3.11/lib/python/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/jameshaberberger/Library/Python/3.11/lib/python/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log1p
# ...

# %%
clustermap, indexer, labels = wgcna.run_wgcna(microglia, adjacency_type="unsigned", cutoff=1, min_cluster_size=10)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 2684 cells and 1063 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.37 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.22 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.22 seconds.
#   Calculated graph and diffusion operator in 0.82 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.07 seconds.
# Calculated MAGIC in 0.89 seconds.
# Power: 1, R^2: 0.9476581518342663
# 1063

# %%
" ".join(microglia.var.iloc[labels==2].index.tolist())
# Out:
# 'HES4 ANKRD65 HES5 HES2 DRAXIN E2F2 ID3 DHDDS SYTL1 NKAIN1 SPOCD1 SLC2A1 PCSK9 PLPP3 DAB1 ANGPTL3 C1orf141 PTGFR TTLL7 CYR61 TGFBR3 SLC44A3 VCAM1 S1PR1 AMY1C SLC16A4 SYCP1 CD160 GJA5 PPIAL4G HIST2H2AA3 HIST2H2AB C1orf56 FLG SMCP S100A9 S100A8 MUC1 C1orf61 HAPLN2 SPTA1 ATP1A2 NHLH1 NR1I3 CFAP126 HSPA6 FCGR2B RGS5 FMO2 FMO1 TNR LHX4 RGS8 LAMC2 OCLM ERVMER61-1 CFH ASPM GPR37L1 LGR6 CHI3L1 FMOD PRELP ZC3H11A CNTN2 CDK18 SPATA45 PROX1 CENPF ITPKB SLC35F3 NID1 OR2L8 IAH1 RHOB VIT CYP1B1 C2orf91 SLC3A1 EPAS1 SOCS5 FOXN2 MEIS1-AS2 ACTG2 GNLY CD8B DUSP2 LYG2 MARCO DBI TUBA3D TMEM163 ERMN GAD1 TTN PPP1R1C FRZB COL3A1 STK17B HSPE1-MOB4 BOLL CD28 KANSL1L FN1 VIL1 IHH TUBA4B DES SCG2 DNER KCNJ13 NEU2 UGT1A1 GBX2 COL6A3 ERFE ITPR1 SRGAP3-AS2 CIDEC SLC6A1 TIMP4 MKRN2OS FBLN2 PP2D1 ZNF385D-AS2 SLC6A20 CXCR6 STAB1 FAM107A PSMD6-AS2 MTRNR2L12 GABRR3 CLDND1 COL8A1 CCDC80 TIGIT ZBTB20-AS2 KBTBD12 GP9 CPB1 TM4SF1 GPR171 VEPH1 SI NAALADL2-AS2 MFN1 SST GMNC CPN2 APOD RNF212 FGFR3 USP17L22 HS3ST1 CPEB2-DT Q
# ...
